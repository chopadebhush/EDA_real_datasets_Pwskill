# %% [markdown]
# #### `Import necessary Library`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df =pd.read_csv("HRDataset_v14.csv")
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.size
# Out:
# 11196

# %%
df.shape
# Out:
# (311, 36)

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %% [markdown]
# ### `check duplicate`

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### there is no duplicate in the data

# %% [markdown]
# ### `Understand the data`

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %% [markdown]
# ### `check null Values`

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# #### `fill the Nan Values`

# %%
df.fillna("0",inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.Salary.sort_values(ascending=False)
# Out:
# 150    250000
# 308    220450
# 131    180000
# 96     178000
# 55     170500
#         ...
# 152     45433
# 176     45395
# 231     45115
# 140     45069
# 310     45046
# Name: Salary, Length: 311, dtype: int64

# %% [markdown]
# #### `Find the Top 10 salary with respect to employee Name`

# %%
a =df.set_index("Employee_Name")

# %%
Top10_Highest =a["Salary"].sort_values(ascending=False).head(10)
Top10_Highest
# Out:
# Employee_Name
# King, Janet         250000
# Zamora, Jennifer    220450
# Houlihan, Debra     180000
# Foss, Jason         178000
# Corleone, Vito      170500
# Monroe, Peter       157000
# Roper, Katie        150290
# Ruiz, Ricardo       148999
# Roup,Simon          140920
# Dougall, Eric       138888
# Name: Salary, dtype: int64

# %%
## We can find also Like 
a["Salary"].nlargest(n=10)
# Out:
# Employee_Name
# King, Janet         250000
# Zamora, Jennifer    220450
# Houlihan, Debra     180000
# Foss, Jason         178000
# Corleone, Vito      170500
# Monroe, Peter       157000
# Roper, Katie        150290
# Ruiz, Ricardo       148999
# Roup,Simon          140920
# Dougall, Eric       138888
# Name: Salary, dtype: int64

# %% [markdown]
# #### `Find Lowest top10 Salary With respet to Employee Name`

# %%
Top10_Lowest =a["Salary"].sort_values(ascending=False).tail(10)
Top10_Lowest
# Out:
# Employee_Name
# Purinton, Janine       46430
# Sadki, Nore            46428
# Dobrin, Denisa  S      46335
# Langton, Enrico        46120
# Perry, Shakira         45998
# Kirill, Alexandra      45433
# Mahoney, Lauren        45395
# Rhoads, Thomas         45115
# Jacobi, Hannah         45069
# Zima, Colleen          45046
# Name: Salary, dtype: int64

# %%
a["Salary"].nsmallest(n=10)
# Out:
# Employee_Name
# Zima, Colleen          45046
# Jacobi, Hannah         45069
# Rhoads, Thomas         45115
# Mahoney, Lauren        45395
# Kirill, Alexandra      45433
# Perry, Shakira         45998
# Langton, Enrico        46120
# Dobrin, Denisa  S      46335
# Sadki, Nore            46428
# Purinton, Janine       46430
# Name: Salary, dtype: int64

# %% [markdown]
# #### `Top 10 Highest Salry EMployee Name`

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x=Top10_Highest.index,y=Top10_Highest)
plt.xticks(rotation=90)
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.title("Highest salary of emplyee Name")
plt.show()

# %% [markdown]
# #### `Top 10 Highest Salry EMployee Name`

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x=Top10_Lowest.index,y=Top10_Lowest)
plt.xticks(rotation=90)
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.title("Lowest salary of emplyee Name")
plt.show()

# %% [markdown]
# #### `Seprate numerical col and object columns`

# %%
cat_col =[col for col in df.columns if df[col].dtypes == "O"]
num_col =[col for col in df.columns if df[col].dtypes != "O"]

# %%
cat_col
# Out:
# ['Employee_Name',
#  'Position',
#  'State',
#  'DOB',
#  'Sex',
#  'MaritalDesc',
#  'CitizenDesc',
#  'HispanicLatino',
#  'RaceDesc',
#  'DateofHire',
#  'DateofTermination',
#  'TermReason',
#  'EmploymentStatus',
#  'Department',
#  'ManagerName',
#  'ManagerID',
#  'RecruitmentSource',
#  'PerformanceScore',
#  'LastPerformanceReview_Date']

# %%
num_col
# Out:
# ['EmpID',
#  'MarriedID',
#  'MaritalStatusID',
#  'GenderID',
#  'EmpStatusID',
#  'DeptID',
#  'PerfScoreID',
#  'FromDiversityJobFairID',
#  'Salary',
#  'Termd',
#  'PositionID',
#  'Zip',
#  'EngagementSurvey',
#  'EmpSatisfaction',
#  'SpecialProjectsCount',
#  'DaysLateLast30',
#  'Absences']

# %% [markdown]
# #### `Distrubution of salary`

# %%
plt.figure(figsize=(12,5))
sns.histplot(x=df["Salary"],kde=True)
plt.xlabel("Salary")
plt.ylabel("count")
plt.show()

# %% [markdown]
# #### `Insight and Observation`
#
# 1. 50K to 1L salary have more count of folks
# 2. Above 1L has got salary less number of folks

# %% [markdown]
# #### `Distrubution Of marriedID`

# %%
df.ManagerID.value_counts()
# Out:
# 20.0    22
# 16.0    22
# 12.0    22
# 18.0    22
# 22.0    21
# 11.0    21
# 19.0    21
# 14.0    21
# 2.0     19
# 4.0     17
# 17.0    14
# 7.0     14
# 39.0    13
# 21.0    13
# 10.0     9
# 13.0     8
# 0        8
# 5.0      7
# 1.0      6
# 6.0      4
# 15.0     3
# 9.0      2
# 3.0      1
# 30.0     1
# Name: ManagerID, dtype: int64

# %%
plt.figure(figsize=(12,7))
sns.displot(data=df,x=df["MarriedID"],kind="kde")
plt.xlabel("married ID")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### `Insight and Observation`
#
# 1. 0.5 to 0.25 ID folks has more count as compare to 0.75 to 1.50

# %% [markdown]
# #### `Distrubution of marital status ID`

# %%
df.MaritalStatusID.value_counts()
# Out:
# 0    137
# 1    124
# 2     30
# 3     12
# 4      8
# Name: MaritalStatusID, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.kdeplot(data=df,x=df["MaritalStatusID"],hue="Sex")
plt.xlabel("Marital Status")
plt.ylabel("Density")
plt.title("Marital status vs density")
plt.show()

# %% [markdown]
# #### `Insight and observations`
#
# 1. Id 0 to 2 have more peoples are married
# 2. Id 0 to 2 have more female are married

# %% [markdown]
# #### `Relationship between GenderID vs Salary`

# %%
plt.figure(figsize=(12,6))
sns.scatterplot( data=df,x=df["GenderID"],y=df["Salary"],hue="Sex",size=10)
plt.xlabel("Gender ID")
plt.ylabel("Salary")
plt.title("GenderID vs Salary")
plt.show()

# %% [markdown]
# ### `Observation and Insight`
#
# 1. female salary is more as compare to male

# %% [markdown]
# #### Barplot of Sex vs Salary

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x=df["Sex"],y=df["Salary"],hue="Sex")
plt.xlabel("Sex")
plt.ylabel("Salary")
plt.title("Sex vs salary")
plt.show()

# %% [markdown]
# #### `Observation and Insight`
#
# 1. male salry is more than female as per the chart

# %% [markdown]
# #### `How many Position in the companyand its percent`

# %%
df_Pos =df["Position"].value_counts()

# %%
plt.figure(figsize=(25,20))
df_Pos.plot.pie(x=df["Position"],labels=df_Pos.index,autopct="%1.1f%%")
plt.title("Postion in company")
plt.legend()
plt.show()

# %% [markdown]
# #### `Observation And Insights`
#
# 1. Product Technician I & Product Technician II have more postion in organzation

# %%
plt.figure(figsize=(12,7))
sns.countplot(data=df,x=df["Position"])
plt.xlabel("Postion",fontsize=20)
plt.ylabel("Count",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### `Male female count state wise`

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x=df["State"],hue="Sex")
plt.xlabel("State",fontsize=(20))
plt.ylabel("Count",fontsize=(20))
plt.legend()
plt.show()

# %% [markdown]
# #### Observation and Insight
#
# 1. MA state Male and female count is more as compare to other state

# %%
df_state =df.State.value_counts()

# %%
plt.figure(figsize=(20,18))
df_state.plot.pie(x=df_state ,labels=df_state.index,autopct="%1.1f%%")
plt.title("% ")
