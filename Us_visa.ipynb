# %% [markdown]
# #### `Import Necessary Library`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv("us_perm_visas.csv")
df.head()
# Out:
#   add_these_pw_job_title_9089 agent_city agent_firm_name agent_state  \
# 0                         NaN        NaN             NaN         NaN
# 1                         NaN        NaN             NaN         NaN
# 2                         NaN        NaN             NaN         NaN
# 3                         NaN        NaN             NaN         NaN
# 4                         NaN        NaN             NaN         NaN
#
#   application_type        case_no case_number case_received_date case_status  \
# 0             PERM  A-07323-97014         NaN                NaN   Certified
# 1             PERM  A-07332-99439         NaN                NaN      Denied
# 2             PERM  A-07333-99643         NaN                NaN   Certified
# 3             PERM  A-07339-01930         NaN                NaN   Certified
# 4             PERM  A-07345-03565         NaN                NaN   Certified
#
#   class_of_admission  ... ri_pvt_employment_firm_to ri_us_workers_considered  \
# ...

# %%
df.tail()
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 374357                         NaN   Buena Park
# 374358                         NaN      Seattle
# 374359                         NaN   Schaumburg
# 374360                         NaN  LOS ANGELES
# 374361                         NaN      Phoenix
#
#                                           agent_firm_name agent_state  \
# 374357                           Law Offices of Yohan Lee          CA
# 374358                         MacDonald Hoague & Bayless          WA
# 374359  International Legal and Business Services Grou...          IL
# 374360                        LAW OFFICES OF JAMES S HONG          CA
# 374361            Fragomen, Del Rey, Bernsen & Loewy, LLP          AZ
#
#        application_type case_no    case_number case_received_date case_status  \
# 374357              NaN     NaN  A-16363-85407         2016-12-29   Withdrawn
# 374358              NaN     NaN  A-16271-56745         2016-12-30   Withdrawn
# ...

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.size
# Out:
# 57651748

# %% [markdown]
# `Check the data type`

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089       object
# agent_city                        object
# agent_firm_name                   object
# agent_state                       object
# application_type                  object
#                                   ...
# wage_offer_to_9089                object
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089     object
# Length: 154, dtype: object

# %%
df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Data columns (total 154 columns):
#  #    Column                                  Non-Null Count   Dtype
# ---   ------                                  --------------   -----
#  0    add_these_pw_job_title_9089             42194 non-null   object
#  1    agent_city                              211454 non-null  object
#  2    agent_firm_name                         206997 non-null  object
#  3    agent_state                             208239 non-null  object
#  4    application_type                        135269 non-null  object
#  5    case_no                                 135269 non-null  object
#  6    case_number                             239093 non-null  object
#  7    case_received_date                      239091 non-null  object
#  8    case_status                             374362 non-null  object
#  9    class_of_admission                      351517 non-null  object
# ...

# %% [markdown]
# #### `Check the duplicate value`

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# `Observation`
#
# 1. In these dataset there is no any duplicated values

# %% [markdown]
# `Check null values`

# %%
df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Data columns (total 154 columns):
#  #    Column                                  Non-Null Count   Dtype
# ---   ------                                  --------------   -----
#  0    add_these_pw_job_title_9089             42194 non-null   object
#  1    agent_city                              211454 non-null  object
#  2    agent_firm_name                         206997 non-null  object
#  3    agent_state                             208239 non-null  object
#  4    application_type                        135269 non-null  object
#  5    case_no                                 135269 non-null  object
#  6    case_number                             239093 non-null  object
#  7    case_received_date                      239091 non-null  object
#  8    case_status                             374362 non-null  object
#  9    class_of_admission                      351517 non-null  object
# ...

# %% [markdown]
# ##### `Observation`
#
# 1. Each and every columns have null values

# %% [markdown]
# `All columns name`

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %% [markdown]
# `Check the decriptive statastics `

# %%
df.describe()
# Out:
#        employer_num_employees  employer_yr_estab  \
# count            2.390130e+05      238958.000000
# mean             2.309387e+04        1984.208267
# std              5.453129e+05          38.470555
# min              0.000000e+00           0.000000
# 25%              7.300000e+01        1980.000000
# 50%              1.200000e+03        1996.000000
# 75%              1.613400e+04        2004.000000
# max              2.635506e+08        2016.000000
#
#        foreign_worker_yr_rel_edu_completed  fw_info_yr_rel_edu_completed  \
# count                         83364.000000                 137198.000000
# mean                           2001.345761                   2002.633603
# std                              91.444715                     89.674423
# min                               0.000000                      0.000000
# 25%                            2003.000000                   2004.000000
# 50%                            2006.000000                   2007.000000
# ...

# %% [markdown]
# `Find the unique values`

# %%
## Function is used to find out unique values
## Function takes 1 argument columns print all unique data
def UniqueVal(col):
    for i in col :
        print(f"{i} unique values are ==> {df[i].unique()}")
        print("=====================================================================================")

# %%
UniqueVal(df.columns)
# Out:
# add_these_pw_job_title_9089 unique values are ==> [nan 'Production Supervisor' 'TRANSMISSION REPAIR HELPER' ...
#  'Software Developers, Applicants' 'Senior SharePoint Developer'
#  'Aircraft Mechanic']
# ...
# agent_city unique values are ==> [nan 'Milwaukee' 'RALEIGH' ... 'East Bruswick' 'DOWNEY' 'Dalton']
# ...
# agent_firm_name unique values are ==> [nan 'Reinhart Boerner Van Deuren s.c.' 'Global Labor Solutions, LLC' ...
#  'Sullivan, Hayes & Quinn, LLC' 'Law offices of Miller and Choe pc'
#  'The Lamboley Law Firm, LLC']
# ...
# agent_state unique values are ==> [nan 'WISCONSIN' 'NORTH CAROLINA' 'COLORADO' 'CALIFORNIA' 'MICHIGAN'
#  'NEW YORK' 'TEXAS' 'PENNSYLVANIA' 'NEW JERSEY' 'MISSOURI' 'FLORIDA'
#  'VIRGINIA' 'OHIO' 'DISTRICT OF COLUMBIA' 'INDIANA' 'GEORGIA'
#  'MASSACHUSETTS' 'ILLINOIS' 'ALABAMA' 'OKLAHOMA' 'WASHINGTON'
#  'CONNECTICUT' 'MINNESOTA' 'ARKANSAS' 'HAWAII' 'MARYLAND' 'UTAH'
#  'PUERTO RICO' 'ARIZONA' 'NEVADA' 'NEW HAMPSHIRE' 'OREGON' 'KANSAS'
# ...

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df.drop("case_no",axis=1,inplace=True)

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %% [markdown]
# `Deal with case status columns`

# %%
df =df[df["case_status"]!= "Withdrawn"]

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired'], dtype=object)

# %% [markdown]
# `Combine the unique values which are same`

# %%
df.loc[df["case_status"]=="Certified-Expired","case_status"]="Certified"

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied'], dtype=object)

# %% [markdown]
# `Null values treatment`

# %%
df.dropna(axis=1,how="all",inplace=True)
df.dropna(axis=0,how="all",inplace=True)

# %%
df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356168 entries, 0 to 374353
# Data columns (total 153 columns):
#  #    Column                                  Non-Null Count   Dtype
# ---   ------                                  --------------   -----
#  0    add_these_pw_job_title_9089             39137 non-null   object
#  1    agent_city                              202716 non-null  object
#  2    agent_firm_name                         198522 non-null  object
#  3    agent_state                             199624 non-null  object
#  4    application_type                        126848 non-null  object
#  5    case_number                             229320 non-null  object
#  6    case_received_date                      229320 non-null  object
#  7    case_status                             356168 non-null  object
#  8    class_of_admission                      335083 non-null  object
#  9    country_of_citizenship                  336896 non-null  object
# ...

# %%
df.application_type.value_counts()
# Out:
# ONLINE      105616
# PERM         19219
# MAILEDIN      2013
# Name: application_type, dtype: int64

# %% [markdown]
# `How many application type people used?`

# %%
plt.figure(figsize=(12,7))
df.application_type.value_counts().plot(kind="bar",color="red")
plt.xlabel("Aplication Type")
plt.ylabel("COunt")
plt.title("Application type vs count")
plt.show()

# %% [markdown]
# `Observation & Insight`
#
# 1. Certied and online Application type used more

# %% [markdown]
# `Which type of agent are avilable?`

# %%
df_agentState =df.agent_state.value_counts()

# %%
## Top 10 Agent state
df_agent =df_agentState.nlargest(n=10)
df_agent
# Out:
# CA            34091
# CALIFORNIA    18844
# NY            15982
# TX            10481
# NEW YORK       9024
# GA             8173
# MA             7899
# IL             6605
# TEXAS          6389
# MI             6298
# Name: agent_state, dtype: int64

# %%
plt.figure(figsize=(12,12))
plt.pie(x=df_agent,labels=df_agent.index,autopct="%1.1f%%")
plt.title("Agents state %")
plt.show()

# %% [markdown]
# `Observation and insights`
#
# 1. certified agent has 68.5 %
# 2. CA Agent has 9.3%

# %% [markdown]
# `How may cases are certified or denied `

# %%
df.case_status.value_counts()
# Out:
# Certified    330519
# Denied        25649
# Name: case_status, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=df["case_status"],palette="viridis")
plt.xlabel("case_status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# `Observation and Insight`
#
# 1. Certified case are 30519
# 2. denied case are 25649

# %% [markdown]
# `I have observed country of citizenship have duplicated columns need to drop it.`

# %%
df.drop("country_of_citzenship",axis=1,inplace=True)

# %% [markdown]
# `Which are Top 10 Country of citizen ship`

# %%
plt.figure(figsize=(12,8))
df["country_of_citizenship"].value_counts().nlargest(n=10).plot(kind="bar",color ="red",)
plt.show()

# %% [markdown]
# `which sector has more econony`?

# %%
df_economic_sector =df.us_economic_sector.value_counts()

# %%
plt.figure(figsize=(20,20))
plt.pie(x=df_economic_sector,labels=df_economic_sector.index,autopct="%1.1f%%")
plt.title("Economy of sectors")
plt.show()

# %% [markdown]
# `Observation and Insights`
#
# 1. IT and Adv Manufacturing has more economy

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'decision_date', 'employer_address_1',
#        'employer_address_2', 'employer_city', 'employer_country',
#        'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
#        'foreign_worker_info_req_experience', 'foreign_worker_info_state',
# ...

# %%
df.decision_date =pd.to_datetime(df.decision_date)

# %%
df["Year"] =df.decision_date.dt.year

# %%
df["Year"]
# Out:
# 0         2012
# 1         2011
# 2         2011
# 3         2011
# 4         2012
#           ...
# 374349    2016
# 374350    2016
# 374351    2016
# 374352    2016
# 374353    2016
# Name: Year, Length: 356168, dtype: int64

# %%
fig,ax =plt.subplots(figsize =(10,8))

sns.countplot(x=df["Year"],hue="case_status",data=df)
ax.set(xlabel ="Visa Application status",ylabel ="No of application")
plt.show()

# %% [markdown]
# `Observation & Insight`
#
# 1. 2016 has more numbers of visa application certified

# %%
fig,ax =plt.subplots(figsize =(10,8))

sns.countplot(x="employer_city",hue="Year",data=df,order=df.employer_city.value_counts().iloc[0:10].index)
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# `Observation & Insight`
#
# 1. City college station has higher visa count
